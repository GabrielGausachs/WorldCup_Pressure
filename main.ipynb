# %% [markdown]
# ### Pressure on players analysis in the WC2022 using pff data

# %% [markdown]
# Loading already cleaned data

# %% [markdown]
# #### Options for analysis
# - Receiver pressure at pass reception: defensive pressure on the receiver at the moment of the pass to pass completion. Demonstrate a negative relationship like in the paper.
#
# - Find players who do not touch the ball much but consistently reduce their own pressure before dangerous receptions or drag defenders to change teammates’ pressure. FOR SURE because this can also be combined with pitch control models and with dangerous accessible space.

# %% [markdown]
# Receiver pressure at pass reception
#
# - Get all passes
# - Labelled them as successfull and unsuccessfull
# - Get the receiver
# - Get the moment of the pass (frame if possible)
# - Calculate the pressur on the receiver in the moment of the pass
# - Does it have a negative correlation too?
#
# Receiver pressure per team in successfull and unsuccessfull passes
#
# Pressure shares in different areas of the pitch. Same split in xT zones and then the same for the completion rate under these shares. (Can this team still complete passes when pressure is high and the location is valuable?)
#
# When the team receives with a high pressure, is there a bad pass from the player that receives the ball, a ball loss of the receiver, failed dribble,...? This is good and can be compare across top teams.
#
#
# PLAYER-LEVEL
#
# Per position:
# number of times a player is tried to be found and his pressure Who receives under pressure the most?
#
# Turnover rate (does this player keep the ball after receiving the ball with high pressure) Who survives pressure the best? See if there is a shot in the next 10 seconds
#
# For every pass tried, check the receiver, then calculate the pressure 1 second before the pass is made, at the moment of the pass and when he receives the ball. (Does he create space for himself?)
#
#
#
#
# Bonus: Passer-receiver pairs and the average pressure for the receiver (Which pairs they try to find eachother without taking into account the pressure the receiver has?)
